# %% [markdown]
# # Tokenization
#
# Tokenization is at the heart of much weirdness of LLMs. Do not brush it off.
#
# *   Why can't LLM spell words? **Tokenization.**
# *   Why can't LLM do super simple string processing tasks like reversing a string? **Tokenization.**
# *   Why is LLM worse at non-English languages (e.g. Japanese)? **Tokenization.**
# *   Why is LLM bad at simple arithmetic? **Tokenization.**
# *   Why did GPT-2 have more than necessary trouble coding in Python? **Tokenization.**
# *   Why did my LLM abruptly halt when it sees the string `<|endoftext|>`? **Tokenization.**
# *   What is this weird warning I get about a "trailing whitespace"? **Tokenization.**
# *   Why the LLM break if I ask it about "SolidGoldMagikarp"? **Tokenization.**
# *   Why should I prefer to use YAML over JSON with LLMs? **Tokenization.**
# *   Why is LLM not actually end-to-end language modeling? **Tokenization.**
# *   What is the real root of suffering? **Tokenization.**
#
# Good tokenization web app: [https://tiktokenizer.vercel.app](https://tiktokenizer.vercel.app)
#
# **Example string:**
#
# ```text
# Tokenization is at the heart of much weirdness of LLMs. Do
# not brush it off.
#
# 127 + 677 = 804
# 1275 + 6773 = 8041
#
# Egg.
# I have an Egg.
# egg.
# EGG.
#
# 만나서 반가워요. 저는 OpenAI에서 개발한 대규모 언어 모델인 ChatGPT입니다. 궁
# 금한 것이 있으시면 무엇이든 물어보세요.
#
# for i in range(1, 101):
#     if i % 3 == 0 and i % 5 == 0:
#         print("FizzBuzz")
#     elif i % 3 == 0:
#         print("Fizz")
#     elif i % 5 == 0:
#         print("Buzz")
#     else:
#         print(i)

# %%
"안녕하세요 👋 (Hello in Korean!)"
# Out:
# '안녕하세요 👋 (Hello in Korean!)'

# %%
#To access unicode code point given single character is given by ord function
ord("h")
# Out:
# 104

# %%
[ord(x) for x in "안녕하세요 👋 (Hello in Korean!)"]
# Out:
# [50504,
#  45397,
#  54616,
#  49464,
#  50836,
#  32,
#  128075,
#  32,
#  40,
#  72,
#  101,
#  108,
#  108,
#  111,
#  32,
#  105,
#  110,
#  32,
#  75,
#  111,
#  114,
#  101,
#  97,
#  110,
#  33,
#  41]

# %% [markdown]
# ### Why can't we use these integers and not have no tokenization at all
# - One reason is the vocabulary will be very large approx 150,000
# - Second unicode is not stable representation as it is always adding stuff
# ## Now for that we have encodings: UTF8, UTF16, UTF32
# These encodings help us to store and process unicode text as binary data

# %%
list("안녕하세요 👋 (Hello in Korean!)".encode("utf-8")) #it has vocabulary size of 256
# Out:
# [236,
#  149,
#  136,
#  235,
#  133,
#  149,
#  237,
#  149,
#  152,
#  236,
#  132,
#  184,
#  236,
#  154,
#  148,
#  32,
#  240,
#  159,
#  145,
#  139,
#  32,
#  40,
#  72,
#  101,
#  108,
#  108,
#  111,
#  32,
#  105,
#  110,
#  32,
#  75,
#  111,
#  114,
#  101,
#  97,
#  110,
#  33,
#  41]

# %% [markdown]
# ### This will increase the context length so we need something to reduce the size of that
# ### so we have byte pair encoding algorithm for the compression
# # BYTE PAIR ENCODING ALGORITHM

# %%
#text from 
text = "Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception."
tokens = text.encode("utf-8") #raw bytes
tokens = list(map(int, tokens)) #convert to the list of integers in range 0..255 for convenience
print('---')
print(text)
print("length:", len(text))
print('---')
print(tokens)
print("length:", len(tokens))
# Out:
# ---
# Ｕｎｉｃｏｄｅ! 🅤🅝🅘🅒🅞🅓🅔‽ 🇺‌🇳‌🇮‌🇨‌🇴‌🇩‌🇪! 😄 The very name strikes fear and awe into the hearts of programmers worldwide. We all know we ought to “support Unicode” in our software (whatever that means—like using wchar_t for all the strings, right?). But Unicode can be abstruse, and diving into the thousand-page Unicode Standard plus its dozens of supplementary annexes, reports, and notes can be more than a little intimidating. I don’t blame programmers for still finding the whole thing mysterious, even 30 years after Unicode’s inception.
# length: 533
# ---
# ...

# %%
chr(101), chr(32)
# Out:
# ('e', ' ')

# %%
def get_stats(ids):
    counts = {} #empty dictionary
    #Pythonic way to iterate consecutive elements
    for pair in zip(ids, ids[1:]):# This built-in Python function takes two or more lists and pairs their elements together side-by-side.
        counts[pair] = counts.get(pair, 0) + 1 #.get(key, default):
    return counts
stats = get_stats(tokens)
# print(stats)
#(v, k) for k, v in stats.items() : This is a generator expression. It loops through the items and actively swaps their positions so the count (v) comes first and
# the pair (k) comes second: (count, (token1, token2))
# .items(): A dictionary method that unpacks the dictionary into a list of tuples: ((token1, token2), count)
print(sorted(((v, k) for k, v in stats.items()), reverse=True))#sorted(iterable, reverse=True)
# Out:
# [(20, (101, 32)), (15, (240, 159)), (12, (226, 128)), (12, (105, 110)), (10, (115, 32)), (10, (97, 110)), (10, (32, 97)), (9, (32, 116)), (8, (116, 104)), (7, (159, 135)), (7, (159, 133)), (7, (97, 114)), (6, (239, 189)), (6, (140, 240)), (6, (128, 140)), (6, (116, 32)), (6, (114, 32)), (6, (111, 114)), (6, (110, 103)), (6, (110, 100)), (6, (109, 101)), (6, (104, 101)), (6, (101, 114)), (6, (32, 105)), (5, (117, 115)), (5, (115, 116)), (5, (110, 32)), (5, (100, 101)), (5, (44, 32)), (5, (32, 115)), (4, (116, 105)), (4, (116, 101)), (4, (115, 44)), (4, (114, 105)), (4, (111, 117)), (4, (111, 100)), (4, (110, 116)), (4, (110, 105)), (4, (105, 99)), (4, (104, 97)), (4, (103, 32)), (4, (101, 97)), (4, (100, 32)), (4, (99, 111)), (4, (97, 109)), (4, (85, 110)), (4, (32, 119)), (4, (32, 111)), (4, (32, 102)), (4, (32, 85)), (3, (118, 101)), (3, (116, 115)), (3, (116, 114)), (3, (116, 111)), (3, (114, 116)), (3, (114, 115)), (3, (114, 101)), (3, (111, 102)), (3, (111, 32)), (3, (108, 108)),
# ...

# %%
top_pair = max(stats, key=stats.get)
top_pair
# Out:
# (101, 32)

# %%
def merge(ids, pair, idx):
    # In the list of ints(ids), replace all consecutive occurences of pair with the new token idx
    newids=[]
    i = 0
    while i < len(ids):
        # If we are not at the very last position AND the pair matches, replace it
        if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
            newids.append(idx)
            i += 2
        else:
            newids.append(ids[i])
            i += 1
    return newids
print(merge([5,6,6,7,9,1], (6,7), 99))

# tokens2 = merge(tokens, top_pair, 256)
# print(tokens2)
# print("length:", len(tokens2))
# Out:
# [5, 6, 99, 9, 1]
